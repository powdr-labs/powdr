# %%
import json

# %%
# %pwd
# Out:
# '/Users/georg/coding/powdr/notebooks'

# %%
pgo_range_constraints = json.load(open("../pgo_range_constraints.json"))
air_id_by_pc = {int(pc): air_id for pc, air_id in pgo_range_constraints["air_id_by_pc"].items()}
column_names_by_air_id = {int(air_id): column_names for air_id, column_names in pgo_range_constraints["column_names_by_air_id"].items()}
column_ranges_by_pc = {int(pc): values for pc, values in pgo_range_constraints["column_ranges_by_pc"].items()}
equivalence_classes_by_block = {int(block_id): eq_classes for block_id, eq_classes in pgo_range_constraints["equivalence_classes_by_block"].items()}

# %% [markdown]
# # Range constraints

# %%
def print_ranges(pc_value):
    air_id = air_id_by_pc[pc_value]
    column_names = column_names_by_air_id[air_id]
    column_ranges = column_ranges_by_pc[pc_value]
    for col_name, (min_val, max_val) in zip(column_names, column_ranges):
        if min_val != max_val:
            print(f"{col_name}: [{min_val}, {max_val}]")
        else:
            print(f"{col_name}: {min_val}")

# %%
print_ranges(0x201ecc + 9 * 4)
# Out:
# from_state__pc: 2105072
# from_state__timestamp: [53182, 5127132]
# rd_ptr: 48
# rs1_ptr: 48
# rs2: 16777200
# rs2_as: 0
# reads_aux__0__base__prev_timestamp: [53150, 5127100]
# reads_aux__0__base__timestamp_lt_aux__lower_decomp__0: [27, 31]
# reads_aux__0__base__timestamp_lt_aux__lower_decomp__1: 0
# reads_aux__1__base__prev_timestamp: 0
# reads_aux__1__base__timestamp_lt_aux__lower_decomp__0: 0
# reads_aux__1__base__timestamp_lt_aux__lower_decomp__1: 0
# writes_aux__base__prev_timestamp: [53182, 5127132]
# writes_aux__base__timestamp_lt_aux__lower_decomp__0: 1
# writes_aux__base__timestamp_lt_aux__lower_decomp__1: 0
# writes_aux__prev_data__0: [16, 216]
# writes_aux__prev_data__1: 0
# writes_aux__prev_data__2: 0
# writes_aux__prev_data__3: 0
# a__0: [0, 200]
# a__1: 0
# a__2: 0
# a__3: 0
# b__0: [16, 216]
# b__1: 0
# b__2: 0
# b__3: 0
# c__0: 240
# c__1: 255
# c__2: 255
# c__3: 255
# opcode_add_flag: 1
# opcode_sub_flag: 0
# opcode_xor_flag: 0
# opcode_or_flag: 0
# opcode_and_flag: 0

# %% [markdown]
# # Equivalences

# %%
equivalence_classes_by_block[2099512][0]
# Out:
# [[1, 29], [1, 37], [3, 6]]

# %%
def column_name(block_id, instruction_idx, col_idx):
    pc = block_id + instruction_idx * 4
    air_id = air_id_by_pc[pc]
    column_names = column_names_by_air_id[air_id]
    return f"instruction[{instruction_idx}].{column_names[col_idx]}"

# %%
def print_equivalence_class(block_id, equivalence_class):
    for cell in equivalence_class:
        name = column_name(block_id, cell[0], cell[1])
        print(f"- {name}")

# %%
def print_equivalence_classes(block_id):
    classes = equivalence_classes_by_block[block_id]
    print(f"Number of equivalence classes: {len(classes)}\n\n")
    for eq_class in classes:
        print("Equivalence Class:")
        print_equivalence_class(block_id, eq_class)
        print()

# %%
print_equivalence_classes(0x201ecc)
# Out:
# Number of equivalence classes: 51
#
#
# Equivalence Class:
# - instruction[6].rs1_aux_cols__base__prev_timestamp
# - instruction[5].from_state__timestamp
#
# Equivalence Class:
# - instruction[5].read_data__0
# - instruction[1].write_data__0
# - instruction[1].read_data__0
# - instruction[5].write_data__0
#
# Equivalence Class:
# - instruction[10].writes_aux__base__prev_timestamp
# - instruction[10].from_state__timestamp
#
# Equivalence Class:
# - instruction[2].write_data__0
# - instruction[6].read_data__0
# - instruction[6].write_data__0
# - instruction[2].read_data__0
#
# Equivalence Class:
# - instruction[8].writes_aux__base__prev_timestamp
# - instruction[8].from_state__timestamp
#
# Equivalence Class:
# - instruction[3].rs1_aux_cols__base__prev_timestamp
# - instruction[2].from_state__timestamp
#
# Equivalence Class:
# - instruction[9].rd_ptr
# - instruction[11].rs2_ptr
# - instruction[9].rs1_ptr
#
# Equivalence Class:
# - instruction[3].read_data__1
# - instruction[7].write_data__1
# - instruction[3].write_data__1
# - instruction[7].read_data__1
#
# Equivalence Class:
# - instruction[5].write_data__2
# - instruction[5].read_data__2
# - instruction[1].read_data__2
# - instruction[1].write_data__2
#
# Equivalence Class:
# - instruction[2].write_data__2
# - instruction[6].read_data__2
# - instruction[6].write_data__2
# - instruction[2].read_data__2
#
# Equivalence Class:
# - instruction[0].from_state__timestamp
# - instruction[1].rs1_aux_cols__base__prev_timestamp
#
# Equivalence Class:
# - instruction[0].write_data__1
# - instruction[0].read_data__1
# - instruction[4].write_data__1
# - instruction[4].read_data__1
#
# Equivalence Class:
# - instruction[4].write_data__2
# - instruction[0].write_data__2
# - instruction[4].read_data__2
# - instruction[0].read_data__2
#
# Equivalence Class:
# - instruction[2].write_data__3
# - instruction[6].read_data__3
# - instruction[6].write_data__3
# - instruction[2].read_data__3
#
# Equivalence Class:
# - instruction[4].from_state__timestamp
# - instruction[5].rs1_aux_cols__base__prev_timestamp
#
# Equivalence Class:
# - instruction[8].c__0
# - instruction[10].c__0
# - instruction[10].rs2
# - instruction[8].rs2
#
# Equivalence Class:
# - instruction[3].from_state__timestamp
# - instruction[8].reads_aux__0__base__prev_timestamp
#
# Equivalence Class:
# - instruction[3].imm
# - instruction[7].imm
#
# Equivalence Class:
# - instruction[6].rd_rs2_ptr
# - instruction[2].rd_rs2_ptr
#
# Equivalence Class:
# - instruction[9].a__0
# - instruction[11].b__0
#
# Equivalence Class:
# - instruction[9].from_state__timestamp
# - instruction[9].writes_aux__base__prev_timestamp
#
# Equivalence Class:
# - instruction[4].read_data__3
# - instruction[0].read_data__3
# - instruction[0].write_data__3
# - instruction[4].write_data__3
#
# Equivalence Class:
# - instruction[1].from_state__timestamp
# - instruction[2].rs1_aux_cols__base__prev_timestamp
#
# Equivalence Class:
# - instruction[3].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[1].mem_as
# - instruction[1].flags__0
# - instruction[3].mem_as
# - instruction[3].flags__0
# - instruction[6].mem_as
# - instruction[2].mem_as
# - instruction[1].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[6].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[4].mem_as
# - instruction[7].mem_as
# - instruction[5].mem_as
# - instruction[2].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[5].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[0].mem_as
# - instruction[7].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__0
# - instruction[0].flags__0
# - instruction[2].flags__0
#
# Equivalence Class:
# - instruction[7].flags__2
# - instruction[2].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[10].reads_aux__0__base__timestamp_lt_aux__lower_decomp__1
# - instruction[5].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[10].b__3
# - instruction[9].writes_aux__prev_data__2
# - instruction[2].imm_sign
# - instruction[2].flags__3
# - instruction[11].a__3
# - instruction[8].writes_aux__prev_data__3
# - instruction[8].c__2
# - instruction[6].rs1_data__3
# - instruction[0].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[9].opcode_sub_flag
# - instruction[10].opcode_sub_flag
# - instruction[11].opcode_bge_flag
# - instruction[6].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].rs2_as
# - instruction[11].reads_aux__1__base__timestamp_lt_aux__lower_decomp__1
# - instruction[9].reads_aux__1__base__timestamp_lt_aux__lower_decomp__1
# - instruction[10].writes_aux__prev_data__3
# - instruction[1].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[11].b__2
# - instruction[11].a_msb_f
# - instruction[11].a__2
# - instruction[10].reads_aux__1__base__timestamp_lt_aux__lower_decomp__0
# - instruction[9].opcode_or_flag
# - instruction[5].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[4].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[6].flags__1
# - instruction[8].reads_aux__1__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].reads_aux__0__base__timestamp_lt_aux__lower_decomp__1
# - instruction[9].opcode_xor_flag
# - instruction[6].is_load
# - instruction[9].a__3
# - instruction[10].rs2_as
# - instruction[4].flags__0
# - instruction[9].opcode_and_flag
# - instruction[0].imm
# - instruction[11].b__1
# - instruction[11].opcode_bgeu_flag
# - instruction[10].reads_aux__1__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].a__3
# - instruction[3].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[9].a__2
# - instruction[9].reads_aux__0__base__timestamp_lt_aux__lower_decomp__1
# - instruction[5].is_load
# - instruction[7].is_load
# - instruction[7].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[5].imm_sign
# - instruction[11].b__3
# - instruction[11].diff_marker__1
# - instruction[0].flags__2
# - instruction[9].reads_aux__1__base__prev_timestamp
# - instruction[1].imm_sign
# - instruction[11].opcode_blt_flag
# - instruction[8].c__3
# - instruction[9].b__3
# - instruction[0].flags__3
# - instruction[4].imm_sign
# - instruction[8].opcode_sub_flag
# - instruction[8].b__3
# - instruction[11].diff_marker__3
# - instruction[7].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[5].flags__2
# - instruction[7].imm_sign
# - instruction[10].opcode_and_flag
# - instruction[10].writes_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[10].opcode_or_flag
# - instruction[0].imm_sign
# - instruction[11].diff_marker__2
# - instruction[4].imm
# - instruction[11].a__1
# - instruction[7].flags__0
# - instruction[9].writes_aux__prev_data__3
# - instruction[1].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[0].rs1_data__3
# - instruction[5].flags__1
# - instruction[9].b__1
# - instruction[3].imm_sign
# - instruction[9].b__2
# - instruction[10].reads_aux__1__base__prev_timestamp
# - instruction[4].rs1_data__3
# - instruction[6].flags__2
# - instruction[6].imm_sign
# - instruction[9].rs2_as
# - instruction[1].flags__2
# - instruction[11].b_msb_f
# - instruction[10].a__3
# - instruction[11].reads_aux__0__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].c__1
# - instruction[2].flags__1
# - instruction[2].flags__2
# - instruction[7].flags__1
# - instruction[10].c__2
# - instruction[3].rs1_data__3
# - instruction[6].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[5].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].writes_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[4].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[5].flags__0
# - instruction[8].reads_aux__1__base__prev_timestamp
# - instruction[8].opcode_and_flag
# - instruction[0].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[6].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[8].reads_aux__1__base__timestamp_lt_aux__lower_decomp__0
# - instruction[1].flags__3
# - instruction[6].flags__0
# - instruction[7].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].opcode_xor_flag
# - instruction[4].flags__2
# - instruction[0].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[4].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[5].rs1_data__3
# - instruction[1].rs1_data__3
# - instruction[3].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[8].opcode_or_flag
# - instruction[10].c__3
# - instruction[9].writes_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[3].flags__1
# - instruction[0].flags__1
# - instruction[2].rs1_aux_cols__base__timestamp_lt_aux__lower_decomp__1
# - instruction[4].is_load
# - instruction[9].a__1
# - instruction[9].writes_aux__prev_data__1
# - instruction[7].rs1_data__3
# - instruction[3].flags__3
# - instruction[9].reads_aux__1__base__timestamp_lt_aux__lower_decomp__0
# - instruction[1].write_base_aux__timestamp_lt_aux__lower_decomp__1
# - instruction[3].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[1].flags__1
# - instruction[10].opcode_xor_flag
# - instruction[10].c__1
# - instruction[2].read_data_aux__base__timestamp_lt_aux__lower_decomp__1
# - instruction[2].rs1_data__3
# - instruction[3].flags__2
# - instruction[4].flags__1
#
# Equivalence Class:
# - instruction[10].reads_aux__0__base__timestamp_lt_aux__lower_decomp__0
# - instruction[6].imm
# - instruction[2].imm
#
# Equivalence Class:
# - instruction[10].rd_ptr
# - instruction[7].rs1_ptr
# - instruction[4].rs1_ptr
# - instruction[5].rs1_ptr
# - instruction[10].rs1_ptr
# - instruction[6].rs1_ptr
#
# Equivalence Class:
# - instruction[7].read_data__3
# - instruction[3].read_data__3
# - instruction[7].write_data__3
# - instruction[3].write_data__3
#
# Equivalence Class:
# - instruction[2].needs_write
# - instruction[6].needs_write
# - instruction[7].needs_write
# - instruction[3].is_load
# - instruction[4].is_valid
# - instruction[8].opcode_add_flag
# - instruction[2].is_valid
# - instruction[9].opcode_add_flag
# - instruction[3].needs_write
# - instruction[7].is_valid
# - instruction[7].flags__3
# - instruction[1].is_valid
# - instruction[5].is_valid
# - instruction[6].is_valid
# - instruction[0].is_load
# - instruction[8].writes_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[1].needs_write
# - instruction[10].opcode_add_flag
# - instruction[5].flags__3
# - instruction[9].writes_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[10].writes_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[11].opcode_bltu_flag
# - instruction[0].is_valid
# - instruction[2].is_load
# - instruction[4].flags__3
# - instruction[11].diff_marker__0
# - instruction[1].is_load
# - instruction[5].needs_write
# - instruction[0].needs_write
# - instruction[4].needs_write
# - instruction[3].is_valid
# - instruction[6].flags__3
#
# Equivalence Class:
# - instruction[1].read_data__3
# - instruction[5].read_data__3
# - instruction[1].write_data__3
# - instruction[5].write_data__3
#
# Equivalence Class:
# - instruction[3].read_data__2
# - instruction[7].read_data__2
# - instruction[3].write_data__2
# - instruction[7].write_data__2
#
# Equivalence Class:
# - instruction[0].write_data__0
# - instruction[4].write_data__0
# - instruction[0].read_data__0
# - instruction[4].read_data__0
#
# Equivalence Class:
# - instruction[1].rs1_ptr
# - instruction[8].rd_ptr
# - instruction[0].rs1_ptr
# - instruction[8].rs1_ptr
# - instruction[3].rs1_ptr
# - instruction[2].rs1_ptr
#
# Equivalence Class:
# - instruction[11].cmp_result
# - instruction[11].cmp_lt
#
# Equivalence Class:
# - instruction[10].reads_aux__0__base__prev_timestamp
# - instruction[7].from_state__timestamp
#
# Equivalence Class:
# - instruction[4].rs1_data__0
# - instruction[10].b__0
# - instruction[5].rs1_data__0
# - instruction[7].rs1_data__0
# - instruction[10].writes_aux__prev_data__0
# - instruction[6].rs1_data__0
#
# Equivalence Class:
# - instruction[5].rd_rs2_ptr
# - instruction[1].rd_rs2_ptr
#
# Equivalence Class:
# - instruction[5].read_data_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[7].read_data_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[6].read_data_aux__base__timestamp_lt_aux__lower_decomp__0
# - instruction[4].read_data_aux__base__timestamp_lt_aux__lower_decomp__0
#
# Equivalence Class:
# - instruction[2].rs1_data__0
# - instruction[8].b__0
# - instruction[1].rs1_data__0
# - instruction[3].rs1_data__0
# - instruction[0].rs1_data__0
# - instruction[8].writes_aux__prev_data__0
#
# Equivalence Class:
# - instruction[6].read_data__1
# - instruction[2].read_data__1
# - instruction[2].write_data__1
# - instruction[6].write_data__1
#
# Equivalence Class:
# - instruction[3].rd_rs2_ptr
# - instruction[7].rd_rs2_ptr
#
# Equivalence Class:
# - instruction[5].imm
# - instruction[1].imm
# - instruction[11].reads_aux__1__base__timestamp_lt_aux__lower_decomp__0
#
# Equivalence Class:
# - instruction[6].from_state__timestamp
# - instruction[7].rs1_aux_cols__base__prev_timestamp
#
# Equivalence Class:
# - instruction[5].write_data__1
# - instruction[5].read_data__1
# - instruction[1].read_data__1
# - instruction[1].write_data__1
#
# Equivalence Class:
# - instruction[8].b__1
# - instruction[0].rs1_data__1
# - instruction[3].rs1_data__1
# - instruction[2].rs1_data__1
# - instruction[1].rs1_data__1
# - instruction[8].writes_aux__prev_data__1
#
# Equivalence Class:
# - instruction[0].rd_rs2_ptr
# - instruction[4].rd_rs2_ptr
#
# Equivalence Class:
# - instruction[9].c__3
# - instruction[9].c__1
# - instruction[9].c__2
#
# Equivalence Class:
# - instruction[10].b__1
# - instruction[10].a__1
# - instruction[5].rs1_data__1
# - instruction[6].rs1_data__1
# - instruction[4].rs1_data__1
# - instruction[7].rs1_data__1
# - instruction[10].writes_aux__prev_data__1
#
# Equivalence Class:
# - instruction[7].read_data__0
# - instruction[3].read_data__0
# - instruction[3].write_data__0
# - instruction[7].write_data__0
#
# Equivalence Class:
# - instruction[8].a__2
# - instruction[10].writes_aux__prev_data__2
# - instruction[1].mem_ptr_limbs__1
# - instruction[2].mem_ptr_limbs__1
# - instruction[0].mem_ptr_limbs__1
# - instruction[10].a__2
# - instruction[0].rs1_data__2
# - instruction[8].writes_aux__prev_data__2
# - instruction[4].mem_ptr_limbs__1
# - instruction[1].rs1_data__2
# - instruction[5].rs1_data__2
# - instruction[8].b__2
# - instruction[6].mem_ptr_limbs__1
# - instruction[4].rs1_data__2
# - instruction[6].rs1_data__2
# - instruction[7].rs1_data__2
# - instruction[10].b__2
# - instruction[3].mem_ptr_limbs__1
# - instruction[3].rs1_data__2
# - instruction[7].mem_ptr_limbs__1
# - instruction[2].rs1_data__2
# - instruction[5].mem_ptr_limbs__1
#
# Equivalence Class:
# - instruction[9].b__0
# - instruction[9].writes_aux__prev_data__0
